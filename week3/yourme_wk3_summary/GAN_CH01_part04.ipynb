# %% [markdown]
# #### Part1 파이토치와 신경망 기초
# ---
# Chapter 4. CUDA 기초

# %%
import torch
import numpy

# %%
# size of square matrix
size = 600

a = numpy.random.rand(size, size)
b = numpy.random.rand(size, size)

# %%
# %%timeit

x = numpy.dot(a,b)
# Out:
# 100 loops, best of 5: 11 ms per loop

# %%
# %%timeit

c = numpy.zeros((size, size))

for i in range(size):
  for j in range(size):
    for k in range(size):
      c[i,j] += a[i,k] * b[k,j]
    pass
  pass
# Out:
# 1 loop, best of 5: 3min 10s per loop

# %%
x = torch.tensor(3.5)
print(x)
# Out:
# tensor(3.5000)

# %%
x = torch.FloatTensor([3.5])
x.type()
# Out:
# 'torch.FloatTensor'

# %%
x = torch.cuda.FloatTensor([3.5])
x.type()

# %%
x = torch.cuda.FloatTensor([3.5])
x.device
# Out:
# device(type='cuda', index=0)

# %%
# caculation with tensor on GPU
y = x * x
y
# Out:
# tensor([12.2500], device='cuda:0')

# %%
aa = torch.cuda.FloatTensor(a)
bb = torch.cuda.FloatTensor(b)

# %%
# %% timeinit
# cc = torch.matmul(aa, bb)

# %%
if torch.cuda.is_abailable():
  torch.set_default_tensor_type(torch.cuda.FloatTensor)
  print("using cuda:", torch.cuda_get_device_name(0))
  pass

device = torch.device("cuda" if torch.cuda.is_available() else = "cpu")

device
