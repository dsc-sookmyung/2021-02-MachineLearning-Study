# %%
import torch
import numpy

# %%
# check if cuda is available
# if yes, set default tensor type to cuda
if torch.cuda.is_available():
  torch.set_default_tensor_type(torch.cuda.FloatTensor)
  print("using cuda:", torch.cuda.get_device_name)
  pass
  
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

device
# Out:
# using cuda: <function get_device_name at 0x7f8871c8c8c0>
# device(type='cuda')

# %%
size = 600
a = numpy.random.rand(size, size)
b = numpy.random.rand(size, size)

# %%
# %%timeit

x = numpy.dot(a, b)
# Out:
# 100 loops, best of 5: 13.7 ms per loop

# %%
x = torch.tensor(3.5)
print(x)
# Out:
# tensor(3.5000)

# %%
x = torch.FloatTensor([3.5])
x.type()
# Out:
# 'torch.FloatTensor'

# %%
x = torch.cuda.FloatTensor([3.5])
x.type()
# Out:
# 'torch.cuda.FloatTensor'

# %%
x.device
# Out:
# device(type='cuda', index=0)

# %%
y = x*x
y
# Out:
# tensor([12.2500], device='cuda:0')

# %%
aa = torch.cuda.FloatTensor(a)
bb = torch.cuda.FloatTensor(b)

# %%
# %%timeit

cc = torch.matmul(aa, bb)
# Out:
# The slowest run took 143.33 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 5: 305 µs per loop
