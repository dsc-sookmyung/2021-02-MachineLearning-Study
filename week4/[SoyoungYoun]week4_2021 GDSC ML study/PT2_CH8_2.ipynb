# %%
from google.colab import drive
drive.mount('./mount')
# Out:
# Mounted at ./mount

# %%
import h5py

import numpy
import matplotlib.pyplot as plt

# %%
with h5py.File('mount/My Drive/Colab Notebooks/myo_gan/mnist_data/celeba/img_align_celeba_20000.h5py', 'r') as file_object:
  for group in file_object:
    print(group)
    pass
# Out:
# img_align_celeba

# %%
with h5py.File('mount/My Drive/Colab Notebooks/myo_gan/mnist_data/celeba/img_align_celeba_20000.h5py', 'r') as file_object:
  dataset = file_object['img_align_celeba']
  image = numpy.array(dataset['6.jpg'])
  plt.imshow(image, interpolation='none')
  pass
